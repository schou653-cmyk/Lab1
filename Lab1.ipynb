# %%
#Lab 1 excdeptions and Debugging
#Saki and Abdul

# %%
from main import compute_BMI, parse_row
from exceptions import TextFormatException, MissingValueException, MeasurementUnitException
# Out:
# ID: 190 Missing value
# ID: 295 Measurement error
# ID: 377 Missing value
# ID: 522 Measurement error
# ID: 777 Format Error
# ID: 832 Missing value
# ID: 843 Measurement error

# %%
#Test BMI calculator without any errors/exceptions

height = 1.80 #meters
weight = 65 #kg

compute_BMI(height, weight)
# Out:
# '20.06'

# %%
# Parse row function test without any errors or eceptions
# Function should list all information into correct numeric values and data types

test = "123, 9/19/1909, adam smith, 80, 2.0"

parse_row(test)
# Out:
# [123, ' 9/19/1909', ' adam smith', 80.0, 2.0]

# %%
#Measurement Unit Error test
#Entered height is of 5.9 feet and not meters

test = "123, 9/19/1909, adam smith, 80, 5.9"

try:

    parse_row(test)

except MeasurementUnitException: print("test pass")
# Out:
# test pass

# %%
# Text format error
#First and last name are seperate into individual elements

test = "123, 9/19/1909,adam, smith, 80, 2.0, "

try:

    parse_row(test)

except TextFormatException: print("test pass")
# Out:
# test pass

# %%
#Missing Value Error
#Weight was not entered

test = "123, 9/19/1909,adam smith,, 2.0"

try:

    parse_row(test)

except MissingValueException: print("test pass")
# Out:
# test pass

# %%
#CVS Output file

output = open('bmi_output.csv')

for row in output:
    print(row)

output.close()
# Out:
# Exam ID,BMI
#
# 1,29.05
#
# 2,23.05
#
# 3,24.12
#
# 4,17.31
#
# 5,13.57
#
# 6,16.44
#
# 7,18.41
#
# 8,24.31
#
# 9,27.02
#
# 10,20.15
#
# 11,19.49
#
# 12,33.65
#
# 13,22.84
#
# 14,24.49
#
# 15,33.31
#
# 16,21.27
#
# 17,32.88
#
# 18,28.06
#
# 19,14.88
#
# 20,22.48
#
# 21,18.91
#
# 22,14.88
#
# 23,19.96
#
# 24,21.61
#
# 25,18.15
#
# 26,22.35
#
# 27,19.82
#
# 28,31.62
#
# 29,11.76
#
# 30,17.10
#
# 31,14.58
#
# 32,36.05
#
# 33,21.19
#
# 34,13.28
#
# 35,24.72
#
# 36,25.18
#
# 37,21.08
#
# 38,24.35
#
# 39,14.20
#
# 40,21.78
#
# 41,15.68
#
# 42,19.29
#
# 43,15.29
#
# 44,32.46
#
# 45,23.89
#
# 46,13.43
#
# 47,32.86
#
# 48,13.42
#
# 49,21.66
#
# 50,34.55
#
# 51,19.91
#
# 52,15.42
#
# 53,24.88
#
# 54,22.92
#
# 55,17.36
#
# 56,22.34
#
# 57,13.83
#
# 58,21.94
#
# 59,25.48
#
# 60,22.03
#
# 61,14.99
#
# 62,21.00
#
# 63,23.78
#
# 64,26.86
#
# 65,17.78
#
# 66,28.91
#
# 67,18.69
#
# 68,13.25
#
# 69,24.44
#
# 70,18.21
#
# 71,25.26
#
# 72,27.47
#
# 73,24.54
#
# 74,33.56
#
# 75,23.10
#
# 76,25.93
#
# ...
