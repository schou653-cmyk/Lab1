# %%
#Lab 1 excdeptions and Debugging
#Saki and Abdul

# %%
from main import compute_BMI, parse_row
from exceptions import TextFormatException, MissingValueException, MeasurementUnitException

# %%
# Testing BMI without any exceptions/errors

height = 1.75 #in meters
weight = 70 #kg

compute_BMI(height,weight)
# Out:
# 22.857142857142858
